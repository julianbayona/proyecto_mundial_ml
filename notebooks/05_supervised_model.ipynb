# %% [markdown]
# # Fase 5 - Modelo supervisado
#
# Este notebook entrena un baseline con `DummyClassifier` y una regresion logistica con `Pipeline`. Usa solo features pre-torneo del dataset supervisado.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path("..") if Path.cwd().name == "notebooks" else Path(".")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.supervised_model import FEATURE_COLUMNS, TARGET_COLUMN, load_supervised_dataset, train_supervised_model

# %%
df = load_supervised_dataset(PROJECT_ROOT)
print(df.shape)
print(df[TARGET_COLUMN].value_counts())
df.head()

# %% [markdown]
# ## Features usadas
#
# Las variables usadas son pre-torneo. No se incluyen goles ni resultados del torneo actual.

# %%
FEATURE_COLUMNS

# %%
artifacts = train_supervised_model(project_root=PROJECT_ROOT)
artifacts["metrics"]

# %% [markdown]
# ## Coeficientes del modelo

# %%
artifacts["coefficients"]

# %% [markdown]
# ## Reporte de clasificacion

# %%
artifacts["model_report"]
